# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sc
import scipy.linalg as la

rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_table('ml-1m/ratings.dat', sep='::', header=None, names=rnames, engine='python')
ratings
# Out:
#          user_id  movie_id  rating  timestamp
# 0              1      1193       5  978300760
# 1              1       661       3  978302109
# 2              1       914       3  978301968
# 3              1      3408       4  978300275
# 4              1      2355       5  978824291
# 5              1      1197       3  978302268
# 6              1      1287       5  978302039
# 7              1      2804       5  978300719
# 8              1       594       4  978302268
# 9              1       919       4  978301368
# 10             1       595       5  978824268
# 11             1       938       4  978301752
# 12             1      2398       4  978302281
# 13             1      2918       4  978302124
# 14             1      1035       5  978301753
# 15             1      2791       4  978302188
# 16             1      2687       3  978824268
# 17             1      2018       4  978301777
# 18             1      3105       5  978301713
# 19             1      2797       4  978302039
# 20             1      2321       3  978302205
# 21             1       720       3  978300760
# 22             1      1270       5  978300055
# 23             1       527       5  978824195
# 24             1      2340       3  978300103
# 25             1        48       5  978824351
# 26             1      1097       4  978301953
# 27             1      1721       4  978300055
# 28             1      1545       4  978824139
# 29             1       745       3  978824268
# ...          ...       ...     ...        ...
# 1000179     6040      2762       4  956704584
# 1000180     6040      1036       3  956715455
# 1000181     6040       508       4  956704972
# 1000182     6040      1041       4  957717678
# 1000183     6040      3735       4  960971654
# 1000184     6040      2791       4  956715569
# 1000185     6040      2794       1  956716438
# 1000186     6040       527       5  956704219
# 1000187     6040      2003       1  956716294
# 1000188     6040       535       4  964828734
# 1000189     6040      2010       5  957716795
# 1000190     6040      2011       4  956716113
# 1000191     6040      3751       4  964828782
# 1000192     6040      2019       5  956703977
# 1000193     6040       541       4  956715288
# 1000194     6040      1077       5  964828799
# 1000195     6040      1079       2  956715648
# 1000196     6040       549       4  956704746
# 1000197     6040      2020       3  956715288
# 1000198     6040      2021       3  956716374
# 1000199     6040      2022       5  956716207
# 1000200     6040      2028       5  956704519
# 1000201     6040      1080       4  957717322
# 1000202     6040      1089       4  956704996
# 1000203     6040      1090       3  956715518
# 1000204     6040      1091       1  956716541
# 1000205     6040      1094       5  956704887
# 1000206     6040       562       5  956704746
# 1000207     6040      1096       4  956715648
# 1000208     6040      1097       4  956715569
#
# [1000209 rows x 4 columns]

# %%
user = np.matrix(ratings.user_id).T
movie = np.matrix(ratings.movie_id).T
rating = np.matrix(ratings.rating).T

Ys = np.hstack([rating,user,movie])
MovieMax = 0
UserMax = 0
for i in range (Ys.shape[0]):
    if(Ys[i,2]>MovieMax):
        MovieMax = Ys[i,2]
    if(Ys[i,1]>UserMax):
        UserMax = Ys[i,1]

userinitial = np.matrix([0]*(UserMax+1)).T 
movieinitial = np.matrix([0]*(MovieMax+1)) 
Y = userinitial*movieinitial
M = Y
Ysize = Ys.shape[0]

A = np.mat(np.random.rand(UserMax+1, 1))
B = np.mat(np.random.rand(1, MovieMax+1))
Ysize
# Out:
# 1000209

# %%
EPOCH = 5
Eta = 0.1
eta = Eta

for i in range(EPOCH):
    E = np.array(M)*np.array(Y - A*B)

    for k in range(Ysize):
        u = Ys[k,1]
        m = Ys[k,2]
        
        err = Ys[k,0] - A[u,0]*B[0,m]
        
        temp_A = A[u,0] + eta*err*B[0,m]
        B[0,m]   = B[0,m] + eta*err*A[u,0]
        A[u,0]   = temp_A
    
    eta = Eta*1./(i+1)
print("end")
# Out:
# end

# %%
res = A*B
for j in range (20):
    
    userinfo = [(0,0)]
    for m in range (MovieMax):
        movieTuple = (res[j,m],m)
        userinfo.append(movieTuple)
        
    userinfo = sorted(userinfo, key=lambda tup: tup[0], reverse=True)     
    
    print("Movie for user " , j , " : ")
    for n in range(10):
        print (userinfo[n])
# Out:
# Movie for user  0  :
# (2.1126125555910868, 3307)
# (2.0389975303600831, 53)
# (2.0018202838492818, 2019)
# (1.9954004835365218, 3245)
# (1.988076375333494, 318)
# (1.9871227048186888, 2329)
# (1.9830982225940748, 2905)
# (1.9668155836793866, 1207)
# (1.9664464845768055, 670)
# (1.9558541161936733, 1204)
# Movie for user  1  :
# (5.2383615681614506, 3307)
# (5.0558282787569331, 53)
# (4.9636448545806244, 2019)
# (4.947726538112879, 3245)
# (4.9295659308447553, 318)
# (4.9272012421751628, 2329)
# (4.9172222742089957, 2905)
# (4.8768484017290561, 1207)
# (4.8759331962652404, 670)
# (4.8496687232518809, 1204)
# Movie for user  2  :
# (4.8406444343151707, 3307)
# (4.6719697943659977, 53)
# (4.5867853004419219, 2019)
# (4.572075565535191, 3245)
# (4.5552937834164204, 318)
# (4.5531086312656175, 2329)
# (4.5438873060254448, 2905)
# (4.5065787776681017, 1207)
# (4.5057330582237629, 670)
# (4.4814626879070065, 1204)
# Movie for user  3  :
# (5.4219344984611206, 3307)
# (5.2330045198672037, 53)
# (5.1375906235134963, 2019)
# (5.1211144662091836, 3245)
# (5.1023174393566437, 318)
# (5.0998698826332385, 2329)
# (5.0895412121184629, 2905)
# (5.0477524792891098, 1207)
# (5.0468052014021456, 670)
# (5.0196203172619276, 1204)
# Movie for user  4  :
# (5.5820260630099101, 3307)
# (5.3875176149837536, 53)
# (5.2892864658669785, 2019)
# (5.2723238228256379, 3245)
# (5.2529717827322449, 318)
# (5.2504519578570781, 2329)
# (5.2398183162986856, 2905)
# (5.1967957021634881, 1207)
# (5.1958204543335027, 670)
# (5.1678328916225054, 1204)
# Movie for user  5  :
# (4.0012232065451663, 3307)
# (3.8617986127997757, 53)
# (3.7913860513006084, 2019)
# (3.7792271469502485, 3245)
# (3.7653555112678587, 318)
# (3.7635492886431101, 2329)
# (3.7559270430832998, 2905)
# (3.7250882257541007, 1207)
# (3.7243891634055157, 670)
# (3.7043275434578837, 1204)
# Movie for user  6  :
# (5.3118639280837936, 3307)
# (5.1267694127384846, 53)
# (5.0332925117499103, 2019)
# (5.0171508365446762, 3245)
# (4.9987354077117452, 318)
# (4.9963375387823641, 2329)
# (4.9862185503755381, 2905)
# (4.9452781696720134, 1207)
# (4.9443501224521391, 670)
# (4.9177171180337815, 1204)
# Movie for user  7  :
# (5.6273143443448888, 3307)
# (5.4312278038453536, 53)
# (5.3321996824703266, 2019)
# (5.315099417543748, 3245)
# (5.2955903698287017, 318)
# (5.2930501010257265, 2329)
# (5.2823301862494958, 2905)
# (5.2389585195963191, 1207)
# (5.2379753593528839, 670)
# (5.2097607270080966, 1204)
# Movie for user  8  :
# (5.266054069392136, 3307)
# (5.0825558211401427, 53)
# (4.9898850710024183, 2019)
# (4.9738826026500345, 3245)
# (4.9556259896685635, 318)
# (4.9532488001161976, 2329)
# (4.9432170785210392, 2905)
# (4.9026297703133848, 1207)
# (4.9017097266328662, 670)
# (4.8753064069702665, 1204)
# Movie for user  9  :
# (4.715962381037123, 3307)
# (4.5516323486562555, 53)
# (4.4686419794513208, 2019)
# (4.4543111279714216, 3245)
# (4.4379615996735264, 318)
# (4.4358327311974675, 2329)
# (4.4268489226310539, 2905)
# (4.3905013621744722, 1207)
# (4.3896774262009588, 670)
# (4.3660321957072101, 1204)
# Movie for user  10  :
# (5.9667141174725415, 3307)
# (5.7588010246806496, 53)
# (5.6538002279099926, 2019)
# (5.6356685960326169, 3245)
# (5.6149829006374787, 318)
# (5.6122894207994243, 2329)
# (5.6009229566356238, 2905)
# (5.5549354180191095, 1207)
# (5.5538929605082474, 670)
# (5.5239766212335235, 1204)
# Movie for user  11  :
# (4.6559518840965159, 3307)
# (4.4937129470443757, 53)
# (4.4117786280991504, 2019)
# (4.3976301363264341, 3245)
# (4.3814886553449988, 318)
# (4.3793868766641602, 2329)
# (4.3705173868248544, 2905)
# (4.334632348116612, 1207)
# (4.3338188967066351, 670)
# (4.3104745511474034, 1204)
# Movie for user  12  :
# (4.7604391378116793, 3307)
# (4.59455929093052, 53)
# (4.5107862304809307, 2019)
# (4.4963202231740453, 3245)
# (4.4798165006874084, 318)
# (4.4776675546200186, 2329)
# (4.4685990187728857, 2905)
# (4.4319086605000457, 1207)
# (4.4310769538962926, 670)
# (4.4072087226488108, 1204)
# Movie for user  13  :
# (4.6632777180287688, 3307)
# (4.50078350868435, 53)
# (4.4187202714794678, 2019)
# (4.4045495179859042, 3245)
# (4.38838263944624, 318)
# (4.3862775537549421, 2329)
# (4.3773941083569783, 2905)
# (4.3414526069015311, 1207)
# (4.3406378755792847, 670)
# (4.3172567992283533, 1204)
# Movie for user  14  :
# (4.2433675192321187, 3307)
# (4.0955052876241593, 53)
# (4.0208315288788965, 2019)
# (4.0079367971615136, 3245)
# (3.9932256837707416, 318)
# (3.9913101529386141, 2329)
# (3.9832266275858661, 2905)
# (3.9505215199147434, 1207)
# (3.9497801520102858, 670)
# (3.9285044515370635, 1204)
# Movie for user  15  :
# (4.7017214664417368, 3307)
# (4.537887665745413, 53)
# (4.4551479047227751, 2019)
# (4.4408603284888413, 3245)
# (4.424560171287947, 318)
# (4.4224377314115459, 2329)
# (4.4134810514861602, 2905)
# (4.3772432507058419, 1207)
# (4.3764218027932769, 670)
# (4.3528479744187232, 1204)
# Movie for user  16  :
# (5.5694697146369379, 3307)
# (5.3753987987554419, 53)
# (5.2773886132306433, 2019)
# (5.2604641263807919, 3245)
# (5.2411556172480918, 318)
# (5.2386414605297231, 2329)
# (5.2280317385493422, 2905)
# (5.1851059005532925, 1207)
# (5.1841328464700513, 670)
# (5.1562082396792777, 1204)
# Movie for user  17  :
# (5.7636011362317561, 3307)
# (5.5627656153302762, 53)
# (5.4613391518433767, 2019)
# (5.4438247390472023, 3245)
# (5.4238432056377102, 318)
# (5.4212414145766026, 2329)
# (5.4102618763450687, 2905)
# (5.365839800039037, 1207)
# (5.3648328288358282, 670)
# (5.33593487199711, 1204)
# Movie for user  18  :
# (5.2017916369941615, 3307)
# (5.0205326448565284, 53)
# (4.9289927695137683, 2019)
# (4.9131855816365082, 3245)
# (4.8951517567886338, 318)
# (4.8928035764300377, 2329)
# (4.8828942734090814, 2905)
# (4.8428022580935126, 1207)
# (4.8418934418413579, 670)
# (4.815812325772292, 1204)
# Movie for user  19  :
# (4.428164094467383, 3307)
# (4.2738625351594415, 53)
# (4.195936770828161, 2019)
# (4.1824804798658741, 3245)
# (4.1671287046987668, 318)
# (4.1651297534379523, 2329)
# (4.1566941945188809, 2905)
# (4.1225647954417148, 1207)
# (4.1217911413284591, 670)
# (4.0995888945296208, 1204)
